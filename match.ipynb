# %%
import PyPDF2
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'any', 'they', "we've", 'yourself', 'weren', "mustn't", 'before', 'the', "aren't", 'me', 'your', 'isn', 'my', 'do', 'o', "wouldn't", 'have', 'he', 'each', 'it', "that'll", 'them', 'more', "doesn't", 'having', 'that', 'or', "i'll", 'yours', 'ourselves', 'who', "i'm", "couldn't", "wasn't", 'not', 'for', 'off', 'than', 'how', 'no', 'her', "it's", 'wouldn', "didn't", 'by', "they'll", 'here', 'd', 'now', 'into', 'out', 'his', 'are', "she'd", 'up', 'hers', 'over', 'was', 'under', 'we', "i'd", 'during', 'hasn', 'did', 'their', 'ours', 'its', "haven't", 'with', 'y', 'because', 'couldn', 'be', 'below', 'don', "we're", 'if', 'at', 'as', 'being', 'very', 'you', 'yourselves', 'only', 'when', 'all', 'both', 'too', 'about', "we'll", "isn't", 'aren', "shan't", 'again', 'those', 'didn', 'then', "it'd", "he's", 'will', "weren't", "they'd", 'm', "hadn't", 'why', 'been', 'there', 'most', 'other', "they're", "you'll", "we'd", 'am', "i've", 'doesn', 'where', 'which', "won't", 'himself', "don't", 'can', 
# ...

# %%
def extract_text_from_pdf(pdf_file):
    text =""
    try:
        reader =PyPDF2.PdfReader(pdf_file)
        for page in reader.pages:
            text += page.extract_text()
    except Exception as e:
        return f"Error Reading PDF :{str(e)}"
    return text

# %%
text = extract_text_from_pdf("Soniya_Thapa_Resume.pdf")
print(text[:500])
# Out:
# Soniya Thapa
# soniyathapa114@gmail.com  •  github.com/soniya -thapa14  •  linkedin.com/in/soniya -thapa  •  Kathmandu , Nepal
#
# EDUCATION
# Bachelor of Computer Engineering  2019 – 2024
# Pokhara University
#
# PROFESSIONAL SUMMARY
# Aspiring AI/ML Engineer with hands -on experience building Retrieval -Augmented Generation (RAG) systems,
# NLP pipelines, and machine learning models. Skilled in Python, LangChain, and Scikit -learn, with experience
# deploying real -world chatbot and prediction

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = text.split()
    words = [word for word in words if word not in stop_words]
    cleaned_text =" ".join(words)
    return cleaned_text

# %%
clean_text(text)
# Out:
# 'soniya thapa soniyathapagmailcom githubcomsoniya thapa linkedincominsoniya thapa kathmandu nepal education bachelor computer engineering pokhara university professional summary aspiring aiml engineer hands experience building retrieval augmented generation rag systems nlp pipelines machine learning models skilled python langchain scikit learn experience deploying real world chatbot prediction systems seeking opportunities apply aiml skills production level environments skills programming python sql html css machine learning scikit learn pandas numpy nlp llms langchain huggingface groq rag pipelines tools streamlit git vs code chromadb serper ap projects nepal knowledge assistant live demo built rag chatbot answers nepal related questions using chromadb vector search live google search via serper implemented smart query routing detects time sensitive questions triggers real time web search automatically added conversation memory follow detection question reformulation using groqs lla
# ...

# %%
def get_match_score(resume_text, job_text):
    if not resume_text or not job_text:
        return 0.0
    vectorize = TfidfVectorizer()
    vectors = vectorize.fit_transform([resume_text, job_text])
    score = cosine_similarity(vectors[0], vectors[1])
    return round(float(score[0][0]) * 100, 2)

# %%
job    = "python django sql pandas machine learning"
resume = "python django sql"

score = get_match_score(job, resume)
print(f"Match Score: {score}%")
# Out:
# Match Score: 57.97%
